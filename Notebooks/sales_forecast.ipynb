# %% [markdown]
# # Sales forecast
#
# Sample notebook, version 1.0.0.

# %%
import pandas as pd

sales = pd.read_csv("sales.csv", parse_dates=["invoiced_at"])
sales.set_index("invoiced_at").resample("MS")["total"].sum()
